# %% [markdown]
# # : : : : CONVERTIR OT's a PDF : : : : :
#
# 🔥version 0.10.1
#
# 🚰 VER 0.10.2 >> Nuevo Campo "notas" : " string " Funcionalidad similar a ic() pero que permita compatibilidad con la libreria DASK y que guarde compatibilidad.
#
#
# COMPATIBILIDAD:
# - GoogleCloud,
# - Linux,
# - Windows
#
# Mediante Variable $HOME

# %%
# !git clone https://github.com/ernestopalacios/eerssa.git

# %% [markdown]
# #1.1 - Definiciones
# Definiciones globales y directorios

# %%
"""
    Nombre con el que se Guardarán los archivos Generados en formato PICKLE.

    Este nombre debe variar dependiendo del proyecto.
"""

VERSION = "0.10.1"

CONTEXT = "code" # "colab" # "win2"

file_prefix = '2024-09_septiembre'  # Importante cambiarlo para evitar sobreescrituras



# Directorio donde se guardaran los archivos generados. Importante el '/' al final
# Mejorar la compatibildad con los dems sistemas

if CONTEXT == 'code':
  save_dir = '/home/vlad/OneDrive/01 JEZO/01 ACTIVIDADES DIARIAS DE TRABAJO DE LAS AGENCIAS/Reporte de Actividades 2024/db'
else:
  save_dir = '/content/drive/MyDrive/Colab_Disk/OT/'


# Combinaciones de nombres con el Prefijo y su Sufijo los cuales de guardaran en el
# Directorio de destino

path_raw    = save_dir + file_prefix + '_0_raw.pkl'
path_dict   = save_dir + file_prefix + '_a_dict.pkl'
path_matriz = save_dir + file_prefix + '_b_matriz.pkl'
path_log    = save_dir + file_prefix + '_c_log.txt'
path_excel  = save_dir + file_prefix + '_d_excel.xlsx'

# %% [markdown]
# # 1 - EXTRACCIÓN
# Funciones y definiciones para convertir de PDF a JSON (dictionary)

# %%
##     *** CARPETA RAÍZ DONDE SE ENCUENTRAN LOS PDF Para convertir ***     ##


if CONTEXT == 'code':
  pdf_dir ='/home/vlad/OneDrive/01 JEZO/01 ACTIVIDADES DIARIAS DE TRABAJO DE LAS AGENCIAS/2024/09 SEPTIEMBRE'
else: 
  pdf_dir ='/content/drive/MyDrive/Colab_Disk/OT/2024/09 SEPTIEMBRE'

# %% [markdown]
# ## 1.1 PyMuPDF (Fitz)

# %% [markdown]
# ### Nombres y Librerias

# %%
# LINUX - VSCODE
if CONTEXT == 'code':
  # %pip install PyMuPDF==1.24.9
  # %pip install icecream==2.1.3
  # %pip install pymongo
  # %pip install "dask[complete]"

# %%
# GOOGLE COLAB CODE
if CONTEXT == 'colab':
  # !pip install PyMuPDF==1.24.9
  # !pip install icecream==2.1.3
  # !pip install pymongo
  # !pip install "dask[complete]"

# %% [markdown]
# ### Align Boxes
#
# This section is used to align the values for the boxes, in order to find and extract tabular data.

# %%
import eerssa

# %%
eerssa.DrawBoxesOt('/home/vlad/GIT/eerssa_gh/eerssa/GestionOT/TestDirectories/0_ImportPdfOT/20_0 colaboradores sin vehiculo.pdf')
# Out:
# '/home/vlad/GIT/eerssa_gh/eerssa/GestionOT/TestDirectories/0_ImportPdfOT/CAMPOS_version_0.10.1.pdf'

# %%
if CONTEXT == 'code':
  test = eerssa.toJSON_ot( '/home/vlad/GIT/eerssa_gh/eerssa/GestionOT/TestDirectories/0_ImportPdfOT/30_Repetido_Responsable_Colaborador.pdf' )
else:
  test = eerssa.toJSON_ot( '/content/drive/MyDrive/Colab_Disk/OT/2024/01 ENERO/04 CUADRILLA YACUAMBI/Orden de trabajo Yacuambi 22-01-2024 (NL).pdf' )
test
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 2
#       1 if CONTEXT == 'code':
# ----> 2   test = eerssa.toJSON_ot( '/home/vlad/GIT/eerssa_gh/eerssa/GestionOT/TestDirectories/0_ImportPdfOT/30_Repetido_Responsable_Colaborador.pdf' )
#       3 else:
#       4   test = eerssa.toJSON_ot( '/content/drive/MyDrive/Colab_Disk/OT/2024/01 ENERO/04 CUADRILLA YACUAMBI/Orden de trabajo Yacuambi 22-01-2024 (NL).pdf' )
#
# AttributeError: module 'eerssa' has no attribute 'toJSON_ot'

# %% [markdown]
# to_pandas(): this method returns the table as a pandas DataFrame.
#
# extract(): this method returns the text content of each table cell as a list of list of strings.

# %% [markdown]
# ## Test PyMuPDF

# %%
"""
    Listado de todos los archivos con extensión .pdf en la ruta `pdf_dir`

"""

list_pdfs = []

# TEST    ****    TEST   **** TEST
if CONTEXT == 'code':
  test_path = '/home/vlad/GIT/eerssa_gh/eerssa/GestionOT/TestDirectories/0_ImportPdfOT'
else:
   test_path = '/content/drive/MyDrive/Colab_Disk/GestionOT/TestDirectories/0_ImportPdfOT'

for path in Path( test_path ).glob("**/*.pdf"):
    list_pdfs.append( str(path) )
    list_pdfs.sort()

len(list_pdfs)
# Out:
# 28

# %%
test_dir = []
for file in list_pdfs:
    test_dir.append( toJSON_ot( file ) )
# Out:
# ot_pdf| 342533457.py:70 in toJSON_ot()- pdf_path: '/home/vlad/GIT/eerssa_gh/eerssa/GestionOT/TestDirectories/0_ImportPdfOT/1_not_pdf.pdf'

# %%
test_dir[13]

# %% [markdown]
# ### DASK

# %%
ic.disable()

# Submit work to happen in parallel
results = []
for file in list_pdfs:
    result = client.submit(toJSON_ot, file)
    results.append(result)

# Gather results back to local computer
results = client.gather(results)

ic.enable()

len(results)
# Out:
# /home/vlad/GIT/eerssa_gh/eerssa/.venv/lib/python3.10/site-packages/distributed/node.py:187: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 41035 instead
#   warnings.warn(
# /tmp/ipykernel_9111/2404920222.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3587047369.py:15: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3587047369.py:15: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3438976481.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/2404920222.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3628808708.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3587047369.py:15: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3587047369.py:15: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# 28

# %% [markdown]
# ## Listado de OTs para convertir a DataFrame

# %%
"""
    Listado de todos los archivos con extensión .pdf en la ruta `pdf_dir`

"""

list_pdfs = []

# Todos los PDF Alrededor de 20.000 ?
for path in Path( pdf_dir ).glob("**/*.pdf"):
    list_pdfs.append( str(path) )
    list_pdfs.sort()

len(list_pdfs)
# Out:
# 387

# %%
list_pdfs[290]
# Out:
# '/home/vlad/OneDrive/01 JEZO/01 ACTIVIDADES DIARIAS DE TRABAJO DE LAS AGENCIAS/2024/09 SEPTIEMBRE/09 CUADRILLA GUALAQUIZA/Orden de trabajo Gualaquiza 22-09-2024 (CL).pdf'

# %%
# D A S K

#from dask.distributed import LocalCluster
#client = LocalCluster().get_client()

ic.disable()
pd.set_option("future.no_silent_downcasting", True)

# Submit work to happen in parallel
ots_raw = []
for file in list_pdfs:
    result = client.submit(toJSON_ot, file)
    ots_raw.append(result)

# Gather results back to local computer
ots_raw = client.gather(ots_raw)

ic.enable()

len(ots_raw)


with open( path_dict, 'wb' ) as fp:  # Guardamos el diccionario en formato JSON
    pickle.dump( ots_raw, fp)

df_dask = pd.DataFrame(ots_raw) # Convert to Pandas Dataframe
df_dask.to_pickle( path_raw )       # Guardamos en formato multidimensional el Dataframe

len(df_dask)
# Out:
# /tmp/ipykernel_9111/3587047369.py:15: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3587047369.py:15: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3587047369.py:15: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3587047369.py:15: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3628808708.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3587047369.py:15: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3628808708.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3438976481.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3628808708.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3438976481.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3438976481.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3628808708.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3628808708.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3438976481.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3438976481.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/2404920222.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3587047369.py:15: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3628808708.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3628808708.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/2404920222.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/2404920222.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/2404920222.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/2404920222.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3628808708.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/2404920222.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3628808708.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3628808708.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3438976481.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3438976481.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3628808708.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3587047369.py:15: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3587047369.py:15: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3628808708.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3438976481.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3628808708.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/2404920222.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3438976481.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3587047369.py:15: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3628808708.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3438976481.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3628808708.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3628808708.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3587047369.py:15: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3587047369.py:15: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3438976481.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/2404920222.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3438976481.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3628808708.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3438976481.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3438976481.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/2404920222.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3438976481.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3438976481.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/2404920222.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3587047369.py:15: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3628808708.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/2404920222.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3628808708.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3438976481.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3438976481.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/2404920222.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3628808708.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3438976481.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3587047369.py:15: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3438976481.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3438976481.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/2404920222.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3628808708.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/2404920222.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/2404920222.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3628808708.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/2404920222.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/2404920222.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3628808708.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3628808708.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3438976481.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/2404920222.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3587047369.py:15: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/2404920222.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3628808708.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3628808708.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3438976481.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3438976481.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3438976481.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3587047369.py:15: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/2404920222.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3438976481.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3438976481.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3587047369.py:15: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/2404920222.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/2404920222.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3438976481.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3628808708.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3438976481.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/2404920222.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3628808708.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3587047369.py:15: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3438976481.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3438976481.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3628808708.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/2404920222.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/2404920222.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3628808708.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/2404920222.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3628808708.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3628808708.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/2404920222.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3628808708.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3438976481.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3587047369.py:15: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3438976481.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3628808708.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3438976481.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/2404920222.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3628808708.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /tmp/ipykernel_9111/3587047369.py:15: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# 387

# %%
len(ots_raw)
# Out:
# 387

# %%
df_dask.sample(5)
# Out:
#     VERSION                                               link   id_ot  \
# 257  0.10.1  /home/vlad/OneDrive/01 JEZO/01 ACTIVIDADES DIA...  137962
# 386  0.10.1  /home/vlad/OneDrive/01 JEZO/01 ACTIVIDADES DIA...  138589
# 50   0.10.1  /home/vlad/OneDrive/01 JEZO/01 ACTIVIDADES DIA...  137674
# 96   0.10.1  /home/vlad/OneDrive/01 JEZO/01 ACTIVIDADES DIA...  137929
# 116  0.10.1  /home/vlad/OneDrive/01 JEZO/01 ACTIVIDADES DIA...  137227
#
#                             cuadrilla  \
# 257  El Pangui Z1 (Cuadrilla. Nro. 4)
# 386              Gualaquiza (Agencia)
# 50      Zamora Z1 (Cuadrilla. Nro. 6)
# 96   Zamora Z1 (Cuadrilla. AP Nro. 4)
# 116   Yacuambi Z1 (Cuadrilla. Nro. 8)
#
#                                     responsable  \
# 257  [MENDIETA MENDIETA HENRRY ALEXANDER, JECU]
# 386       [BUELE UYAGUARI CESAR CRISTIAN, ELAG]
# 50          [SILVA ARMIJOS ROMEL EDUARDO, LIE2]
# 96          [MORALES RIVERA LUIS ALBERTO, JECU]
# 116          [LOZANO SIGCHO NAUN ENRIQUE, JECE]
#
#                                          colaboradores diaSemana  \
# 257  {'total': 2, 'nombres': [['OCHOA CUEVA JONATHA...   viernes
# 386  {'total': 1, 'nombres': [['MEDINA DIAZ BYRON E...     lunes
# 50                         {'total': 0, 'nombres': []}    martes
# 96   {'total': 3, 'nombres': [['CABRERA CABRERA MIG...   viernes
# 116  {'total': 3, 'nombres': [['CABRERA GONZALEZ LU...    martes
#
#                         fecha                         fechaInicio  \
# 257 2024-09-20 00:00:00-05:00  viernes, 20 de septiembre del 2024
# 386 2024-09-30 00:00:00-05:00    lunes, 30 de septiembre del 2024
# 50  2024-09-17 00:00:00-05:00   martes, 17 de septiembre del 2024
# 96  2024-09-20 00:00:00-05:00  viernes, 20 de septiembre del 2024
# 116 2024-09-10 00:00:00-05:00   martes, 10 de septiembre del 2024
#
#               fechaFinal  ...  \
# 257  20/09/2024 17:05:00  ...
# 386  30/09/2024 17:05:00  ...
# 50   17/09/2024 17:03:00  ...
# 96   20/09/2024 20:00:00  ...
# 116  10/09/2024 17:00:00  ...
#
#                                           precauciones  \
# 257  Respetar las 5 reglas de oro. Cumplir con el r...
# 386                  Cumplir regalmento interno EERSSA
# 50   Cumplir con las cinco reglas de oro. Coordinar...
# 96   Cumplir con el código de ética de la EERSSA. D...
# 116  Cumplir con el reglamento de trabajo de la EER...
#
#                                carencias accidente observaciones  numeracion  \
# 257                                             NO                       196
# 386                                             NO                       219
# 50   MOTOSIERRA EN MANTENIMIENTO EN LOJA        NO                        95
# 96                                              NO                       190
# 116                                             NO                       213
#
#                       gerencia     estado  \
# 257  OPERACIÓN Y MANTENIMIENTO  TERMINADO
# 386           COMERCIALIZACIÓN  TERMINADO
# 50   OPERACIÓN Y MANTENIMIENTO  TERMINADO
# 96   OPERACIÓN Y MANTENIMIENTO  TERMINADO
# 116  OPERACIÓN Y MANTENIMIENTO  TERMINADO
#
#                                                 firmas  \
# 257  [MENDIETA MENDIETA HENRRY ALEXANDER, PALACIOS ...
# 386  [BUELE UYAGUARI CESAR CRISTIAN, REIBAN ABRIL C...
# 50   [SILVA ARMIJOS ROMEL EDUARDO, PALACIOS MERINO ...
# 96   [MORALES RIVERA LUIS ALBERTO, PALACIOS MERINO ...
# 116  [LOZANO SIGCHO NAUN ENRIQUE, PALACIOS MERINO E...
#
#                                            actividades exito
# 257  [{'Item': '1', 'Actividad': 'PROG', 'Descipcio...  True
# 386  [{'Item': '1', 'Actividad': 'PROG', 'Descipcio...  True
# 50   [{'Item': '1', 'Actividad': 'PROG', 'Descipcio...  True
# 96   [{'Item': '1', 'Actividad': 'PROG', 'Descipcio...  True
# 116  [{'Item': '1', 'Actividad': 'PROG', 'Descipcio...  True
#
# [5 rows x 31 columns]

# %% [markdown]
# # Exportar kilometrajes
#
# 🐞 HAY UN ERROR cuando dos OT tienen la misma Fecha
#
#
# Lo normal sería utilizar PyMongoDriver para descargar los docuemtos;
# Luego convertirlos a Dataframe, que es el paso en el cual nos encontramos

# %% [markdown]
# Nueva idea:
#
# creo una nueva columna que calcula el día de la semana en base al indice con DateTimeObject... luego... los días en los que no coincide el día calculado con el día que viene de la OT son los días adicionales que fueron insertados, por lo tanto cambio los elementos que necesito cambiar en esas filas y voilá, listo.

# %%
# Out:
# miércoles

# %%
import pandas as pd
import pickle
import locale
from datetime import datetime


path_raw = '/content/drive/MyDrive/Colab_Disk/OT/2024-08_agosto_0_raw.pkl'



def get_day_name_spanish(date_time_obj):
    """
        Translates a DateTimeObject and returns the name of the day in Spanish.

        Parameters:
        date_time_obj (datetime): The input DateTimeObject.

        Returns:
        str: The name of the day in Spanish.
    """

    day_name = date_time_obj.strftime("%A").lower()

    day_mapping = {
        'monday': 'lunes',
        'tuesday': 'martes',
        'wednesday': 'miércoles',
        'thursday': 'jueves',
        'friday': 'viernes',
        'saturday': 'sábado',
        'sunday': 'domingo'
    }

    if day_name in day_mapping:
        day_name = day_mapping[day_name]
    else:
        day_name = None

    return day_name

df = pd.read_pickle( path_raw )
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 328 entries, 0 to 327
# Data columns (total 31 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   VERSION        328 non-null    object
#  1   link           328 non-null    object
#  2   id_ot          328 non-null    int64
#  3   cuadrilla      328 non-null    object
#  4   responsable    328 non-null    object
#  5   colaboradores  328 non-null    object
#  6   diaSemana      328 non-null    object
#  7   fecha          328 non-null    datetime64[ns, America/Guayaquil]
#  8   fechaInicio    328 non-null    object
#  9   fechaFinal     328 non-null    object
#  10  sitio          328 non-null    object
#  11  descripcion    328 non-null    object
#  12  tEstimado      328 non-null    object
#  13  vehiculo       328 non-null    object
#  14  kmInicial      328 non-null    int64
#  15  kmFinal        328 non-null    int64
#  16  kmRecorrido    328 non-null    int64
#  17  trabajo        328 non-null    object
#  18  riesgos        328 non-null    object
#  19  seguridad      328 non-null    object
#  20  epps           328 non-null    object
#  21  precauciones   328 non-null    object
#  22  carencias      328 non-null    object
#  23  accidente      328 non-null    object
#  24  observaciones  328 non-null    object
#  25  numeracion     328 non-null    int64
#  26  gerencia       328 non-null    object
#  27  estado         328 non-null    object
#  28  firmas         328 non-null    object
#  29  actividades    328 non-null    object
#  30  exito          328 non-null    bool
# dtypes: bool(1), datetime64[ns, America/Guayaquil](1), int64(5), object(24)
# memory usage: 77.3+ KB

# %%
sin_exito = df[df.exito == False]
sin_exito
# Out:
# Empty DataFrame
# Columns: [VERSION, link, id_ot, cuadrilla, responsable, colaboradores, diaSemana, fecha, fechaInicio, fechaFinal, sitio, descripcion, tEstimado, vehiculo, kmInicial, kmFinal, kmRecorrido, trabajo, riesgos, seguridad, epps, precauciones, carencias, accidente, observaciones, numeracion, gerencia, estado, firmas, actividades, exito]
# Index: []
#
# [0 rows x 31 columns]

# %%
# PRE - PROCESAMIENTO para elaborar Informe de Kilometrajes.

# Descargo el archivo correspondiente definida previamente en la variable path_raw
df = pd.read_pickle( path_raw )

# Expongo el número del vehículo como una columna.
df['nro_vehiculo'] = df['vehiculo'].apply(lambda x: x.get('numero') if isinstance(x, dict) else None)

# Filtro las columnas relevantes al reporte de kilometrajes.
df = df[['fecha','diaSemana','fechaFinal','sitio','kmInicial','kmFinal','kmRecorrido','nro_vehiculo']]

# Elimino las filas en las cuales nro_vehiculo == "·"
df = df[df.nro_vehiculo != "·"]


df
# Out:
#                         fecha  diaSemana           fechaFinal  \
# 0   2024-08-01 00:00:00-05:00     jueves  01/08/2024 17:05:00
# 1   2024-08-02 00:00:00-05:00    viernes  02/08/2024 17:15:00
# 2   2024-08-05 00:00:00-05:00      lunes  05/08/2024 17:05:00
# 5   2024-08-08 00:00:00-05:00     jueves  08/08/2024 20:10:00
# 6   2024-08-09 00:00:00-05:00    viernes  09/08/2024 12:41:00
# ..                        ...        ...                  ...
# 322 2024-08-23 00:00:00-05:00    viernes  23/08/2024 17:05:00
# 324 2024-08-26 00:00:00-05:00      lunes  26/08/2024 18:01:00
# 325 2024-08-27 00:00:00-05:00     martes  27/08/2024 18:10:00
# 326 2024-08-28 00:00:00-05:00  miércoles  28/08/2024 17:00:00
# 327 2024-08-29 00:00:00-05:00     jueves  29/08/2024 17:00:00
#
#                                                  sitio  kmInicial  kmFinal  \
# 0    Pachicutza, San Francisco El Padmi, Los Encuen...      88049    88224
# 1    Zamora, San Francisco de La Quebrada de Cumbar...      88230    88302
# 2                          Zamora, Timbara, Cumbaratza      88405    88565
# 5                                               Zamora      54367    54413
# 6                                         Namirez Bajo     120616   120671
# ..                                                 ...        ...      ...
# 322  El Pangui, El Guismi, Pachicutza, Tundayme, Sa...      24840    24879
# 324  Pakintza, Machinaza alto, Machinaza Bajo, Guis...      24879    24963
# 325  El Pangui, El Guismi, San Gabriel, El Miasi, E...      24963    25062
# 326  El Pangui, El Guismi, Quimi, Machinza, San Roq...      25062    25107
# 327    El Pangui, Miasi, Guismi, San Roque, San Andres      25107    25170
#
#      kmRecorrido nro_vehiculo
# 0            175        R-159
# 1             72        R-159
# 2            160        R-159
# 5             46         2-91
# 6             55        2-110
# ..           ...          ...
# 322           39        4-118
# 324           84        4-118
# 325           99        4-118
# 326           45        4-118
# 327           63        4-118
#
# [300 rows x 8 columns]

# %%
print(df['nro_vehiculo'].unique())
# Out:
# ['R-159' '2-91' '2-110' 'R-126' '2-61' '2-112' '4-62' 'R-171' '4-52'
#  '4-36' '2-21' '2-102' '2-45' '4-100' '4-118']

# %% [markdown]
# - Agrupar por cada tipo de vehiculo,
# - rellenar fechas faltantes,

# %%
df_zmra = (df[df.nro_vehiculo == 'R-126']
           .sort_values(by='fecha')
          )

df_zmra['diaFecha'] = df_zmra['fecha'].apply(lambda x: get_day_name_spanish(x))

diasDescanso = df_zmra['diaSemana'] != df_zmra['diaFecha']

df_zmra.loc[diasDescanso,'sitio'] = 'NO HAY RECORRIDO EN ESTE DÍA'
df_zmra.loc[diasDescanso,'fechaFinal'] = 'Descanso'

df_zmra[['fecha','diaFecha','kmInicial','kmFinal','kmRecorrido','sitio', 'kmFinal', 'nro_vehiculo']]
# Out:
#                        fecha   diaFecha  kmInicial  kmFinal  kmRecorrido  \
# 26 2024-08-01 00:00:00-05:00     jueves     263620   263690           70
# 27 2024-08-02 00:00:00-05:00    viernes     263789   263889          100
# 28 2024-08-03 00:00:00-05:00     sábado     263890   263942           52
# 29 2024-08-04 00:00:00-05:00    domingo     263942   264022           80
# 30 2024-08-05 00:00:00-05:00      lunes     264026   264115           89
# 31 2024-08-06 00:00:00-05:00     martes     264119   264200           81
# 32 2024-08-07 00:00:00-05:00  miércoles     264204   264274           70
# 33 2024-08-08 00:00:00-05:00     jueves     264278   264340           62
# 34 2024-08-09 00:00:00-05:00    viernes     264344   264414           70
# 35 2024-08-10 00:00:00-05:00     sábado     264418   264488           70
# 36 2024-08-11 00:00:00-05:00    domingo     264588   264658           70
# 37 2024-08-12 00:00:00-05:00      lunes     264673   264831          158
# 38 2024-08-13 00:00:00-05:00     martes     264835   264915           80
# 39 2024-08-14 00:00:00-05:00  miércoles     264980   265030           50
# 40 2024-08-15 00:00:00-05:00     jueves     265040   265140          100
# 41 2024-08-16 00:00:00-05:00    viernes     265144   265235           91
# 42 2024-08-17 00:00:00-05:00     sábado     265340   265429           89
# 43 2024-08-19 00:00:00-05:00      lunes     265460   265550           90
# 44 2024-08-20 00:00:00-05:00     martes     265554   265614           60
# 45 2024-08-21 00:00:00-05:00  miércoles     265619   265749          130
# 46 2024-08-22 00:00:00-05:00     jueves     265799   266001          202
# 47 2024-08-23 00:00:00-05:00    viernes     266007   266167          160
# 48 2024-08-24 00:00:00-05:00     sábado     266290   266394          104
# 49 2024-08-26 00:00:00-05:00      lunes     266584   266665           81
# 50 2024-08-27 00:00:00-05:00     martes     266670   266736           66
# 51 2024-08-28 00:00:00-05:00  miércoles     266740   266829           89
# 52 2024-08-29 00:00:00-05:00     jueves     266840   267046          206
# 53 2024-08-29 00:00:00-05:00     jueves     267046   267050            4
# 54 2024-08-30 00:00:00-05:00    viernes     267060   267131           71
# 55 2024-08-31 00:00:00-05:00     sábado     267271   267312           41
#
#                                                 sitio  kmFinal nro_vehiculo
# 26                              Nuevo Quito, Conguime   263690        R-126
# 27                                 Yawi,Nuevo Paraiso   263889        R-126
# 28                                  Natenza, Guayzimi   263942        R-126
# 29                                Paquisha Bellavista   264022        R-126
# 30                              La Libertad, Conguime   264115        R-126
# 31                           Chinapintza, La Libertad   264200        R-126
# 32                              Conguime, La Libertad   264274        R-126
# 33                            Nuevo Paraiso, Conguime   264340        R-126
# 34             Shaime Nuevo Paraíso Heroes Del Cóndor   264414        R-126
# 35             Shaime Nuevo Paraíso Heroes Del Cóndor   264488        R-126
# 36                             La Herradura ,Guayzimi   264658        R-126
# 37  Conguime, Chinapintza, Selva Alegre, Nuevo Par...   264831        R-126
# 38                 Conguime, La Libertad, Santa Lucia   264915        R-126
# 39                        Guayzimi, Conguime, Nankais   265030        R-126
# 40                                 Guayzimi, Congüime   265140        R-126
# 41                                SumaK Yacu, Mayaycu   265235        R-126
# 42                                  Nankais, Paquisha   265429        R-126
# 43                           Paquisha - Puerto Minero   265550        R-126
# 44             Paquisha, Puerto Minero, Las Orquídeas   265614        R-126
# 45                                           Conguime   265749        R-126
# 46                                         Yayu, Yawi   266001        R-126
# 47                                               Yawi   266167        R-126
# 48                                    Shaime, Nankais   266394        R-126
# 49                           Nuevo Quito, Chinapintza   266665        R-126
# 50                           Nuevo Quito, Chinapintza   266736        R-126
# 51                                           San Luis   266829        R-126
# 52                       Héroes del Cóndor, San Luis,   267046        R-126
# 53                                           Guayzimi   267050        R-126
# 54                           Las Orquídeas, San Ramón   267131        R-126
# 55                                Guayzimi, Wunguinza   267312        R-126

# %%
df_zmra = (df[df.nro_vehiculo == 'R-126']
           .sort_values(by='fecha')
           .set_index('fecha')
           .resample('D')
           .ffill()
           .reset_index()
          )

df_zmra['diaFecha'] = df_zmra['fecha'].apply(lambda x: get_day_name_spanish(x))

diasDescanso = df_zmra['diaSemana'] != df_zmra['diaFecha']

df_zmra.loc[diasDescanso,'sitio'] = 'NO HAY RECORRIDO EN ESTE DÍA'
df_zmra.loc[diasDescanso,'fechaFinal'] = 'Descanso'

df_zmra[['fecha','diaFecha','kmInicial','kmRecorrido','sitio', 'kmFinal', 'nro_vehiculo']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3790         try:
# -> 3791             return self._engine.get_loc(casted_key)
#    3792         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'fecha'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-89-f587e5f25d0e> in <cell line: 9>()
#       7           )
#       8
# ----> 9 df_zmra['diaFecha'] = df_zmra['fecha'].apply(lambda x: get_day_name_spanish(x))
#      10
#      11 diasDescanso = df_zmra['diaSemana'] != df_zmra['diaFecha']
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3891             if self.columns.nlevels > 1:
#    3892                 return self._getitem_multilevel(key)
# -> 3893             indexer = self.columns.get_loc(key)
#    3894             if is_integer(indexer):
#    3895                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3796             ):
#    3797                 raise InvalidIndexError(key)
# -> 3798             raise KeyError(key) from err
#    3799         except TypeError:
#    3800             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'fecha'

# %% [markdown]
# **Modelo de como se debe llenar**
#
# | Dias | Kilometraje Inicial | Recorrido | Trabajo | Lugar |
# |------|---------------------|-----------|---------|-------|
# |Lunes | 256,485  | 89 | ATENCION DE DAÑOS | Zamora, El Limon |
# |Martes| 256,585  | 100| ATENCION DE DAÑOS | Zamora, El Limon |
#
# etc, etc
#
# - Caminar la columna de día, arriba hacia abajo, si se repite el día borrar cambiar la nota de Lugar por: "EL VEHÍCULO PERMANECE EN AGENCIA"
#
# - También cambio el nombre del día y coloco "Descanso"
#
# Nota: puede haber uno o más días repetidos...

# %% [markdown]
# ---

# %%
# Carga de archivos, todo 2023
import pandas as pd

# Lista de dictionaries
dict_1823 = pd.read_pickle( "/content/drive/MyDrive/Colab_Disk/OT/v081_18_23_dict_array.pkl" )
df_dask = pd.DataFrame( dict_1823 )
df_dask.info()


"""
   Exportar los kilometros recorridos de acuerdo a cada id_ot
"""

df_recorridos = df_dask[[ 'id_ot', 'kmInicial', 'kmFinal','fecha' ]]

def dia_de_fecha_larga( fecha_larga ):
    try:
        dia = fecha_larga.split(',')[0]

    except:
        dia = '·'

    return dia

def anio_de_fecha_larga( fecha_larga ):
    try:
        anio = fecha_larga.split(' ')[-1]

    except:

        anio = '1900'

    return anio


def km_str_to_int( odometro ):

    try:
        respuesta = int(odometro.replace(',',''))

    except:
        respuesta = 0

    return respuesta

def id_no_comas ( id ):
    try:
        respuesta = id.replace(',' , '')
    except:
        respuesta = "0"

    return respuesta

fcha_test = "jueves, 07 de marzo del 2019"
print( dia_de_fecha_larga( fcha_test ) )
print( anio_de_fecha_larga( fcha_test) )
print( km_str_to_int( '·' ) )
print( km_str_to_int( '99,123' ) )

df_recorridos['dia'] = df_recorridos['fecha'].apply( lambda x: dia_de_fecha_larga(x) )
df_recorridos['anio'] = df_recorridos['fecha'].apply( lambda x: anio_de_fecha_larga(x) )
df_recorridos['odo_inicial'] = df_recorridos['kmInicial'].apply( lambda x: km_str_to_int(x) )
df_recorridos['odo_final'] = df_recorridos['kmFinal'].apply( lambda x: km_str_to_int(x) )
df_recorridos['kmRecorridos'] = df_recorridos['odo_final'] - df_recorridos['odo_inicial']

df_recorridos['id_ot'] = df_recorridos['id_ot'].apply( lambda x: id_no_comas(x) )

"""
   Exportar los kilometros recorridos de acuerdo a cada id_ot del año 2023
"""

df_recorridos_2023 = df_recorridos[ df_recorridos.anio == '2023']

##### Sample the Dataframe

df_recorridos_2023.sample(5)

df_recorridos_2023.info()

df_recorridos_2023['kmRecorridos'].describe()

# Ajuste de valores erroneos
df_recorridos_2023.loc[15718,'kmRecorridos'] = 31

df_recorridos_2023

# Exportar a Excel.

df_recorridos_2023.to_excel('kilometrajes_DICIEMBRE_2023_for_R.xlsx')

#### Una vez se tiene las columnas de fechaInicio y fechaFin y tiempo

matriz_actividades.iloc[1095]

#### Opcional, cargar archivo Pickle desde memoria   🔙  DESDE AQUI

# %% [markdown]
# # Usando DASK convierte los PDF a Dict y Dataframe
#
# Genera muchos errores, q no tienen mucho sentido, hay q buscar la forma, teoréticamente es posible, pero hay q trabajarlo más.

# %%
"""
    DASK || Local Parallel
    A partir de una lista con las rutas completas de los archivos.
    Utiliza la librería DASK para paralelizar en los núcelos del sistema
    la ejecución.

    Utiliza tabula-py la cual es un wrapper para JVM y utiliza JPipe
"""
ots_raw = []

for pdf in list_pdfs :
    ots_raw.append(delayed(toJSON_ot)(pdf))

dc_resultado = dask.compute(ots_raw, scheduler='processes')
df_dask = pd.DataFrame(dc_resultado[0])

#    Guarda a disco la variable obtenida.

df_dask.to_pickle( path_raw )       # Guardamos en formato multidimensional el Dataframe

with open( path_dict, 'wb' ) as fp:  # Guardamos el diccionario en formato JSON
    pickle.dump( dc_resultado[0], fp)


len(df_dask)

# %% [markdown]
# # 2 - REVISIÓN Y CORRECCIÓN
# Una vez contamos con el PDF en formato de Dataframe y JSON (Dictionary) tenemos dos caminos
#
# ## 2.1 Calificación 🛠 (falta implementar)
# Aquí revisamos la OT y resaltamos y generamos la primera parte del LOG.txt, la intención es que se pueda corregir la OT antes de finalizarla,

# %% [markdown]
# ## 2.2 Creación de Matriz de Actividades
# Convertimos el Dataframe multidimensional a un formato de Matriz (2D) Filas-Columnas, durante la transformación se ejecutan correcciones más frecuentes, fechas, horas, con la intención de que la matriz sea lo más correcta posible. Los cambios realizados serán registrados en la segunda sección de LOG.txt.
#
# Se transforma el texto expandiendo las abreviaciones y errores comunes de escritura.
#
# A partir de esta matriz se generará los Informes y se podra Exportar/Importar a Excel para la revisión manual y actualización de OT.

# %%
"""
    Cargamos el Dataset de OT's desde el directorio de trabajo.

    path_raw = " "    # En caso de necesitar cargar un archivo  ... _0_raw.pkl   diferente
                      # Es mejor configurarlo en la primera celda del Notebook
"""

# !pip install Unidecode

import pandas as pd
import math
import pickle
import uuid
import numpy as np
from   numpy import nan

from nltk.probability import FreqDist
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn import metrics

from unidecode import unidecode

from pprint import pprint
import re

nltk.download('stopwords')
nltk.download('punkt')
stopword_es = nltk.corpus.stopwords.words('spanish')




df_dask = pd.read_pickle( path_raw )  # Cargamos en formato multidimensional el Dataframe

# %% [markdown]
# ### Definiciones de funciones para crear la Matriz de Actividades

# %% [markdown]
# #### organizarActidades

# %%
def organizarActividades( ot_df ):

    actividades = pd.DataFrame( ot_df['actividades'] )
    actividades = actividades[actividades.evento.notnull()]

    if len(actividades) == 0:
        return actividades


    actividades = actividades.reset_index()

    """····························································
            Validar y Corregir Fecha y Hora.
       ·························································"""


    fInicio = actividades[['item','fechaInicio','fechaFin']].dropna()

    try:

        fInicio['solofechaI'] = fInicio['fechaInicio'].apply( lambda x: re.findall( '\d{4}-\d{2}-\d{2}', x)[0])
        fInicio['solofechaF'] = fInicio['fechaInicio'].apply( lambda x: re.findall( '\d{4}-\d{2}-\d{2}', x)[0])

        fechaModa = fInicio.solofechaI.mode().values[0] # fecha 'moda' en el arreglo

    except:
        # Si en ningun lado existe una Fecha, toma la Fecha final, (si existe)
        if( ot_df['fechaFinal'] != "·" ):
            fechaModa = ot_df['fechaFinal'].split()[0]

        else:
            fechaModa = '16/09/1988' # no es posible obtener una fecha.


    """····························································
            Etiquetar eventos 'LABORA'
       ·························································"""

    etiq_labora = actividades.query( 'actividad.isnull()', engine = 'python' )

    try:

        #  |SE LAB___  // mayusculas o minusculas
        etiq_SE_LABORA = etiq_labora.evento.str.contains('^se lab', case = False, regex = True )
        index_labora = etiq_SE_LABORA[etiq_SE_LABORA].index.values

        for fila in index_labora:
            actividades.at[fila,'actividad'] = 'LABORA'
            actividades.at[fila,'fechaInicio'] = fechaModa + " 00:00:01"
            actividades.at[fila,'fechaFin'] = fechaModa + " 00:00:02"


        #  |Labora_  // mayusculas o minusculas
        etiq_LABORA = etiq_labora.evento.str.contains('^labora ', case = False, regex = True )
        index_labora = etiq_LABORA[etiq_LABORA].index.values

        for fila in index_labora:
            actividades.at[fila,'actividad'] = 'LABORA'
            actividades.at[fila,'fechaInicio'] = fechaModa + " 00:00:01"
            actividades.at[fila,'fechaFin'] = fechaModa + " 00:00:02"

    except:
        index_labora = None



    """····························································
            Etiquetar eventos 'INFO'
       ·························································"""

    indexIni = 0


    # ¿Es el primer Item Informativo. ej DIA FESTIVO?.
    if( type(actividades['fechaInicio'][0]) is float
            and   type(actividades['fechaFin'][0]) is float):

        actividades.at[indexIni,'actividad'] = 'INFO'
        actividades.at[indexIni,'fechaInicio'] = fechaModa + " 00:00:01"
        actividades.at[indexIni,'fechaFin'] = fechaModa + " 00:00:02"




    """····························································
            Organización de Fechas y Hora 'YQ'

       En el caso de existir "huecos" en las actividades, se las
       rellena con la siguiente válida, sea Inicial o Final, no
       importa, se toma la siguiente válida y se la llena
       ·························································"""


    #   | -- | o  |  =>   |  o  |  o  |
    #   caso especial, primera fila sin Hora Inicial. Se duplica y dt = 0
    if( type(actividades['fechaInicio'][0]) is float
            and not (type(actividades['fechaFin'][0]) is float) ):
        actividades.at['fechaInicio'][0] = actividades.at['fechaFin'][0]

    #   |  o | o  |  =>   |  o  |  o  |
    #   | -- | o  |  =>   |  o  |  o  |

    ulitmaFechaCorrecta = None
    filaDondeFalta = None
    fechaQueFalta = None

    for fila in actividades.index:

        # | o | o |   Ambas fechas correctas
        if( not type(actividades['fechaInicio'][fila]) is float
            and not (type(actividades['fechaFin'][fila]) is float) ):

            ulitmaFechaCorrecta = actividades['fechaFin'][fila]

            if( filaDondeFalta != None  ): # Hay un hueco por llenar

                if( fechaQueFalta == 'fechaInicio' ):
                    actividades.at[filaDondeFalta,'fechaInicio'] = actividades['fechaFin'][fila]
                elif( fechaQueFalta == 'fechaFin' ):
                    actividades.at[filaDondeFalta,'fechaFin'] = actividades['fechaInicio'][fila]

                filaDondeFalta = None
                fechaQueFalta = None

        # | - | o |
        if( type(actividades['fechaInicio'][fila]) is float
            and not (type(actividades['fechaFin'][fila]) is float) ):

            ulitmaFechaCorrecta = actividades['fechaFin'][fila]

            if( filaDondeFalta == None ): # No hay huecos previos, reportar este como Hueco
                filaDondeFalta = fila
                fechaQueFalta = 'fechaInicio'
            else:                       # Mover la fechaFinal a la que falta

                actividades.at[filaDondeFalta,fechaQueFalta]= actividades['fechaFin'][fila]

                actividades.at[fila,'fechaFin'] = float('NaN')
                filaDondeFalta = None
                fechaQueFalta = None

        # | o | - |
        if( not type(actividades['fechaInicio'][fila]) is float
            and (type(actividades['fechaFin'][fila]) is float) ):

            ulitmaFechaCorrecta = actividades['fechaInicio'][fila]

            if( filaDondeFalta == None ): # No hay huecos previos, reportar este como Hueco
                filaDondeFalta = fila
                fechaQueFalta = 'fechaFin'
            else:                       # Mover la fechaInicial a la que falta

                actividades.at[filaDondeFalta,fechaQueFalta] = actividades['fechaInicio'][fila]
                actividades.at[fila,'fechaInicio'] = float('NaN')
                filaDondeFalta = None
                fechaQueFalta = None


    """····························································
            Consolidar Items adicionales en uno solo
       ·························································"""
    backup = actividades

    try:

        for iteraciones in range( actividades['fechaInicio'].isna().sum() ):
        #while( actividades['fechaInicio'].isnull().values.any() ):

            fila = 1
            totalIdx = len(actividades.index)

            while fila < totalIdx:
                if( type(actividades.at[actividades.index[fila],'fechaInicio']) is float ):  # AND or OR ?
                    data = actividades.at[ actividades.index[fila-1],'evento' ]
                    actividades.at[ actividades.index[fila-1],'evento' ] = data + '\r' + actividades.at[ actividades.index[fila],'evento' ]
                    actividades = actividades.drop(actividades.index[fila])
                    fila = totalIdx
                fila = fila + 1

            """ Lo programo de esta manera ya que al hacer el Drop no se actualizan los indices
                si uso un lazo FOR. Al hacerlo de esta manera cada vez leo los indices tomando
                en cuenta aquellos que ya elimine. y funciona.
            """

        actividades.item = actividades.item.astype(int)

    except:

         actividades = backup


    return actividades

# %% [markdown]
# #### ConvertirOT_a_ActividadesCSV

# %%
def ConvertirOT_a_ActividadesCSV( ot_df ):

    """ Convierte una fila del Dataframe que contiene las OTs y
        devuelve un nuevo dataframe exponienda cada una de las
        actividades de acuerdo al formato descrito.
    """

    if ot_df['exito'] != True:
        return False

    if ot_df['actividades'] == "·":
        return False

    # campos generales a cada una de las actividad
    cuadrilla     = ot_df['cuadrilla']
    primario      = False    # Se obtendrá del SIG (Sistema de Info Geograf)
    horasExtra    = False    # Actividad fuera de horario normal
    desconexion   = False    # ML
    id_ot         = ot_df['id_ot']
    responsable   = ot_df['responsable']
    colaboradores = ot_df['colaboradores']
    vehiculo      = ot_df['vehiculo']
    sitio         = ot_df['sitio']
    dia           = ot_df['fecha']  # solo el nombre del dia de labores: lunes, martes, ...
    fecha         = ot_df['fecha']  # Convertir a Python Time Object
    archivo       = ot_df['link']   # solo el nombre de archivo PDF

    # obtiene el día de la semana: lunes, martes, ....
    try:
        dia = dia.split(',')[0]
    except:
        dia = "·"

    # Convierte 'fecha' a objeto de datetime en Pandas
    try:
        fecha = fecha.split(' ')
        mes = fecha[3]
        dict_mes = {'enero':'01','febrero':'02','marzo':'03','abril':'04',
                    'mayo':'05','junio':'06','julio':'07','agosto':'08',
                    'septiembre':'09','octubre':'10','noviembre':'11','diciembre':'12'}
        for nombre in dict_mes.keys():
            mes = mes.replace(nombre, dict_mes[nombre])

        fecha = fecha[5] +'-'+ mes + '-' + fecha[1]
    except:
        fecha = "·"

    # Obtiene nombre del archivo a PDF
    try:
        archivo = basename(archivo)
    except:
        archivo = "·"

    # Obtener las Actividades

    actividades = organizarActividades( ot_df )
    if len(actividades) == 0:
        return



    if len(colaboradores) == 0:
        colaboradores = "·"
    else:
        colaboradores = ';'.join(colaboradores)

    """
        Se añaden las Columnas con los valores comunes a cada fila de actividad

        VALIDAR UNA MEJOR FORMA DE HACER ESTO EN PANDAS PARA EVITAR ERRORES CUANDO
        SE EJECUTA EN UN GRAN CANTIDAD DE OTS

    """

    actividades['uuid'] = actividades.apply(lambda x: uuid.uuid4(), axis=1)
    actividades.insert( 1, 'cuenta'        , "·" )
    actividades.insert( 2, 'confianza'     , 0.0 )
    actividades.insert( 3, 'cuadrilla'     , cuadrilla  )
    actividades.insert( 4, 'primario'      , primario   )
    actividades.insert( 5, 'horasExtra'    , horasExtra )
    actividades.insert( 8, 'desconexion'   , desconexion)
    actividades.insert( 9, 'id_ot'         , id_ot      )
    actividades.insert( 1, 'responsable'   , responsable)
    actividades.insert( 2, 'colaboradores' , colaboradores )
    actividades.insert( 3, 'vehiculo'      , vehiculo   )
    actividades.insert( 4, 'sitio'         , sitio      )
    actividades.insert( 5, 'dia'           , dia        )
    actividades.insert( 6, 'fecha'         , fecha      )
    actividades.insert( 7, 'archivo'       , archivo    )

    """
        Se reorganizan las columanas
    """

    actividades = actividades[['uuid','item','confianza','cuenta',
                                'evento','redes','alimentador',
                                'tipo','actividad','cuadrilla',
                                'primario','fechaInicio','fechaFin',
                                'horasExtra','desconexion',
                                'responsable','colaboradores',
                                'vehiculo','sitio',
                                'dia','fecha','id_ot','archivo'
                                ]]


    # cambiar los valores para mejorar la lectura y visualización
    actividades = actividades.replace( np.nan, "·", regex=True )

    return( actividades )

# %% [markdown]
# ### Funcion de convresión a Matriz de actividad

# %%
"""
    Convertir los DataFrame de OT's a Matriz de Actividades

"""
matriz_actividades = pd.DataFrame()

for i in range( (len(df_dask) ) ):

    try:
        nueva = ConvertirOT_a_ActividadesCSV( df_dask.iloc[ i ] )

        if isinstance(nueva, pd.DataFrame):
            matriz_actividades = pd.concat( [ matriz_actividades, nueva ], ignore_index=True)

    except:
        print( f"Error en el Indice: {i}" )


matriz_actividades = matriz_actividades[['uuid','item','confianza','cuenta',
                                'evento','redes','alimentador',
                                'tipo','actividad','cuadrilla',
                                'primario','fechaInicio','fechaFin',
                                'horasExtra','desconexion',
                                'responsable','colaboradores',
                                'vehiculo','sitio',
                                'dia','fecha','id_ot','archivo'
                                ]]

# Guardar archivo Pickle a disco
matriz_actividades.to_pickle( path_matriz )

len(matriz_actividades)
# Out:
# <ipython-input-6-cd9f49ce2ba4>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fInicio['solofechaI'] = fInicio['fechaInicio'].apply( lambda x: re.findall( '\d{4}-\d{2}-\d{2}', x)[0])
# <ipython-input-6-cd9f49ce2ba4>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fInicio['solofechaF'] = fInicio['fechaInicio'].apply( lambda x: re.findall( '\d{4}-\d{2}-\d{2}', x)[0])
# <ipython-input-6-cd9f49ce2ba4>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fInicio['solofechaI'] = fInicio['fechaInicio'].apply( lambda x: re.findall( '\d{4}-\d{2}-\d{2}', x)[0])
# 3236

# %% [markdown]
# ### Explorar matriz de actividades

# %%
matriz_actividades.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3236 entries, 0 to 3235
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   uuid           3236 non-null   object
#  1   item           3236 non-null   int64
#  2   confianza      3236 non-null   float64
#  3   cuenta         3236 non-null   object
#  4   evento         3236 non-null   object
#  5   redes          3236 non-null   object
#  6   alimentador    3236 non-null   object
#  7   tipo           3236 non-null   object
#  8   actividad      3236 non-null   object
#  9   cuadrilla      3236 non-null   object
#  10  primario       3236 non-null   bool
#  11  fechaInicio    3236 non-null   object
#  12  fechaFin       3236 non-null   object
#  13  horasExtra     3236 non-null   bool
#  14  desconexion    3236 non-null   bool
#  15  responsable    3236 non-null   object
#  16  colaboradores  3236 non-null   object
#  17  vehiculo       3236 non-null   object
#  18  sitio          3236 non-null   object
#  19  dia            3236 non-null   object
#  20  fecha          3236 non-null   object
#  21  id_ot          3236 non-null   object
#  22  archivo        3236 non-null   object
# dtypes: bool(3), float64(1), int64(1), object(18)
# memory usage: 515.2+ KB

# %%
matriz_actividades['responsable'].unique()  # Nombres de las personas que han elaborado Ordenes de Trabajo
# Out:
# array(['LOZANO SIGCHO NAUN ENRIQUE', 'CABRERA GONZALEZ WILMER DAVID',
#        'ALEJANDRO PACHAR AGUSTIN EDUARDO',
#        'BARRAZUETA GONZAGA SERVIO GUILLERMO',
#        'OCHOA JARAMILLO ANGEL CLAUDIO', 'MACAS CURIPOMA RAMIRO HOMERO',
#        'QUIROGA ORDONEZ CARLOS HERNAN',
#        'MENDIETA MENDIETA HENRRY ALEXANDER', 'VERA SANCHEZ LIVIO STALIN',
#        'LITUMA CORDOVA CESAR RUBEN', 'GUZMAN BARROS MARCO FERNANDO',
#        'YAURE DIAZ RAMIRO GABRIEL', 'MORALES RIVERA LUIS ALBERTO',
#        'JARA NARVAEZ GALO SILVERIO', 'CORONEL TORRES RUSBEL ISRAEL',
#        'BUELE UYAGUARI CESAR CRISTIAN', 'AMBULUDI SILVA FAUSTO JOEL',
#        'POMA GUAMAN LUIS ANTONIO', 'CUADRADO LEON RAUL EFREN',
#        'CHAMBA CANGO PEDRO ROSALINO', 'SILVA ARMIJOS ROMEL EDUARDO',
#        'RIVERA GUAMAN SEGUNDO PATRICIO', 'RIOS RIOS FRANCISCO FERNANDO',
#        'LEON CUEVA LUIS ALBERTO', 'PALACIOS MERINO ERNESTO VLADIMIR'],
#       dtype=object)

# %%
matriz_actividades.query( " fecha == '·' " )[['id_ot','responsable','evento','fechaInicio','fechaFin']]  # OTS sin fecha inicial - se deberian corregir
# Out:
# Empty DataFrame
# Columns: [id_ot, responsable, evento, fechaInicio, fechaFin]
# Index: []

# %%
matriz_actividades.query( " actividad == '·' " )[['id_ot','responsable','fecha','evento','fechaInicio','fechaFin']]  # OTS sin actividad - solamente informativas
# Out:
#         id_ot                  responsable       fecha  \
# 1437  122,930    YAURE DIAZ RAMIRO GABRIEL  2024-01-25
# 1458  122,886    YAURE DIAZ RAMIRO GABRIEL  2024-01-24
# 1476  122,779    YAURE DIAZ RAMIRO GABRIEL  2024-01-23
# 1508  122,648  MORALES RIVERA LUIS ALBERTO  2024-01-20
# 1509  122,648  MORALES RIVERA LUIS ALBERTO  2024-01-20
# 1582  121,820    YAURE DIAZ RAMIRO GABRIEL  2024-01-07
# 1613  121,774    YAURE DIAZ RAMIRO GABRIEL  2024-01-05
# 1693  121,694  MORALES RIVERA LUIS ALBERTO  2024-01-05
# 1734  123,009    YAURE DIAZ RAMIRO GABRIEL  2024-01-26
#
#                                                  evento          fechaInicio  \
# 1437  En El Pangui se prepara material, se equipa ve...  2024-01-25 08:00:00
# 1458  En el Pangui se prepara material, se equipa ve...  2024-01-24 08:00:00
# 1476  En el Pangui se prepara material, se equipa ve...  2024-01-23 08:00:00
# 1508  En el sector de Chamico se espera para confirm...  2024-01-20 14:00:00
# 1509   Alimentación y traslado de Chamico hacia Zamora.  2024-01-20 15:15:00
# 1582  En Agencia Zamora se equipa vehículo de herram...  2024-01-07 15:53:00
# 1613  En Agencia Zamora se equipa vehículo con herra...  2024-01-05 17:45:00
# 1693  8 luminarias de 150 W Na de 1NP, transformador...  2024-01-05 17:10:00
# 1734  En Agencia Yantzaza se coordina trabajos, se r...  2024-01-26 08:00:00
#
#                  fechaFin
# 1437  2024-01-25 08:10:00
# 1458  2024-01-24 08:10:00
# 1476  2024-01-23 08:05:00
# 1508  2024-01-20 15:15:00
# 1509  2024-01-20 16:06:00
# 1582  2024-01-07 16:05:00
# 1613  2024-01-05 17:55:00
# 1693  2024-01-05 17:05:00
# 1734  2024-01-26 08:20:00

# %%
matriz_actividades.query( " fechaInicio == '·' " )[['id_ot','responsable','evento','fechaInicio','fechaFin']]   # Actividades sin fecha de Inicio, se debería corregir.
# Out:
# Empty DataFrame
# Columns: [id_ot, responsable, evento, fechaInicio, fechaFin]
# Index: []

# %% [markdown]
# ## 2.3 Correción de OT  ⏪  continuar aqui
#
# Pendientes:
#
# * Las Conversiones de texto deben estar establecidas en un documento de Google Sheets que será una peuqueña 'base de datos' que se ira actualizando y mejorando.

# %% [markdown]
# #### limpiar_texto_actividad
#
# Limpia el texto para calcular la actividad, pero no modifica el Dataset

# %%
def limpiar_texto_actividad( actividad ):

    # Operaciones
    txt = unidecode(actividad)  # Quitar tildes y caracteres especiales
    txt = txt.lower()           # todo a minusculas
    txt = re.sub( r'[^\w\s]',' ', txt ) # Eliminar puntuacion


    """
        Definición de palabras a reemplzarzar
        Esta lista se irá ampliando de manera iterativa.

        a futuro cambiar esta lista por un GoogleSheet con las palabras
        que se desee cambiar
    """
    palabras = {
            "#"             : "nro",
            "est"           : "estructura",
            "est."          : "estructura",
            "est."          : "estructura",
            "estructuras"   : "estructura",
            "poste"         : "estructura",
            "tiraf"         : "tirafusible",
            "med."          : "medidor",
            "med"           : "medidor",
            "med"           : "medidor",
            "cc"            : "Centro de Control",
            "trafo"         : "transformador",
            "tranfo"        : "transformador",
            "breiker"       : "breaker",
            "  "            : " ",
        }

    keys = (re.escape(k) for k in palabras.keys())
    pattern = re.compile(r'\b(' + '|'.join(keys) + r')\b')

    resultado = pattern.sub(lambda x: palabras[x.group()], txt)

    return resultado


"""
    Dado el texto de una actividad, devuelve la cuenta a la que pertenece y el nivel de confianza.
"""

def calificar_actividad( actividad ):

    clasificador_actividad_v1 = 'NB_clasif_activ_2024_03.pkl'
    nb_clf = pickle.load(open(clasificador_actividad_v1, 'rb'))

    vect_filename = 'NB_vectorizer.pkl'
    vectorizer = pickle.load(open(vect_filename, 'rb'))

    texto = limpiar_texto_actividad( actividad )

    pred = nb_clf.predict( vectorizer.transform( [texto] ) )

    proba = nb_clf.predict_proba( vectorizer.transform( [texto] ) )

    return ( pred[0] )

# %% [markdown]
# #### ordenarFechaStr

# %%
def ordenarFechaStr( texto ):
    try:
        fecha, hora = texto.split(' ')

        if '/' in fecha:
            dia, mes, anio = fecha.split('/')
            respuesta = anio +'-'+ mes +'-'+ dia +' '+ hora
        else:
            respuesta = texto
    except:
        respuesta = texto

    return respuesta

# %% [markdown]
# ### Cambiar/Mejorar texto de Actividades

# %% [markdown]
# ### Calificacion de Actividades

# %%
matriz_actividades['cuenta'] = matriz_actividades['evento'].apply( lambda x: calificar_actividad(x) )

# %% [markdown]
# ---
#
# OLD

# %% [markdown]
# #### Limpieza de Dataset - ya ejecutado para convertir StringFechas a DateTime Object

# %%
matriz_actividades['fechaInicio'] = matriz_actividades['fechaInicio'].apply( lambda x: ordenarFechaStr(x))
matriz_actividades['fechaFin'] = matriz_actividades['fechaFin'].apply( lambda x: ordenarFechaStr(x))

# %%
matriz_actividades['fechaInicio'] = pd.to_datetime( matriz_actividades['fechaInicio'], format='%Y-%m-%d %H:%M:%S')
matriz_actividades['fechaFin'] = pd.to_datetime( matriz_actividades['fechaFin'], format='%Y-%m-%d %H:%M:%S')

# %% [markdown]
# ### exportar kilometrajes para 06MBID

# %%
# Carga de archivos, todo 2023
import pandas as pd

# Lista de dictionaries
dict_1823 = pd.read_pickle( "/content/drive/MyDrive/Colab_Disk/OT/v081_18_23_dict_array.pkl" )
df_dask = pd.DataFrame( dict_1823 )
df_dask.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19256 entries, 0 to 19255
# Data columns (total 30 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   link              19256 non-null  object
#  1   id_ot             19210 non-null  object
#  2   cuadrilla         19209 non-null  object
#  3   responsable       19210 non-null  object
#  4   responsableFirma  19209 non-null  object
#  5   colaboradores     19209 non-null  object
#  6   fecha             19209 non-null  object
#  7   fechaInicio       19209 non-null  object
#  8   fechaFinal        19209 non-null  object
#  9   sitio             19209 non-null  object
#  10  descripcion       19209 non-null  object
#  11  testimado         19209 non-null  object
#  12  vehiculo          19209 non-null  object
#  13  propietario       19209 non-null  object
#  14  chofer            19209 non-null  object
#  15  kmInicial         19209 non-null  object
#  16  kmFinal           19209 non-null  object
#  17  trabajo           19209 non-null  object
#  18  riesgos           19209 non-null  object
#  19  seguridad         19209 non-null  object
#  20  precauciones      19209 non-null  object
#  21  carencias         19209 non-null  object
#  22  accidente         19209 non-null  object
#  23  observaciones     19209 non-null  object
#  24  numeracion        19209 non-null  object
#  25  gerencia          19209 non-null  object
#  26  estado            19209 non-null  object
#  27  firmas            19209 non-null  object
#  28  actividades       19209 non-null  object
#  29  exito             19256 non-null  bool
# dtypes: bool(1), object(29)
# memory usage: 4.3+ MB

# %%
"""
   Exportar los kilometros recorridos de acuerdo a cada id_ot
"""

df_recorridos = df_dask[[ 'id_ot', 'kmInicial', 'kmFinal','fecha' ]]

# %%
def dia_de_fecha_larga( fecha_larga ):
    try:
        dia = fecha_larga.split(',')[0]

    except:
        dia = '·'

    return dia

def anio_de_fecha_larga( fecha_larga ):
    try:
        anio = fecha_larga.split(' ')[-1]

    except:

        anio = '1900'

    return anio


def km_str_to_int( odometro ):

    try:
        respuesta = int(odometro.replace(',',''))

    except:
        respuesta = 0

    return respuesta

def id_no_comas ( id ):
    try:
        respuesta = id.replace(',' , '')
    except:
        respuesta = "0"

    return respuesta

fcha_test = "jueves, 07 de marzo del 2019"
print( dia_de_fecha_larga( fcha_test ) )
print( anio_de_fecha_larga( fcha_test) )
print( km_str_to_int( '·' ) )
print( km_str_to_int( '99,123' ) )
# Out:
# jueves
# 2019
# 0
# 99123

# %%
df_recorridos['dia'] = df_recorridos['fecha'].apply( lambda x: dia_de_fecha_larga(x) )
df_recorridos['anio'] = df_recorridos['fecha'].apply( lambda x: anio_de_fecha_larga(x) )
df_recorridos['odo_inicial'] = df_recorridos['kmInicial'].apply( lambda x: km_str_to_int(x) )
df_recorridos['odo_final'] = df_recorridos['kmFinal'].apply( lambda x: km_str_to_int(x) )
df_recorridos['kmRecorridos'] = df_recorridos['odo_final'] - df_recorridos['odo_inicial']

df_recorridos['id_ot'] = df_recorridos['id_ot'].apply( lambda x: id_no_comas(x) )
# Out:
# <ipython-input-17-c58018136e9b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_recorridos['dia'] = df_recorridos['fecha'].apply( lambda x: dia_de_fecha_larga(x) )
# <ipython-input-17-c58018136e9b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_recorridos['anio'] = df_recorridos['fecha'].apply( lambda x: anio_de_fecha_larga(x) )
# <ipython-input-17-c58018136e9b>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_recorridos['odo_inicial'] = df_recorridos['kmInicial'].apply( lambda x: km_str_to_int(x) )
# <ipython-input-17-c58018136e9b>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_recorridos['odo_final'] = df_recorridos['kmFinal'].apply( lambda x: km_str_to_int(x) )
# <ipython-input-17-c58018136e9b>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_recorridos['kmRecorridos'] = df_recorridos['odo_final'] - df_recorridos['odo_inicial']
# <ipython-input-17-c58018136e9b>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_recorridos['id_ot'] = df_recorridos['id_ot'].apply( lambda x: id_no_comas(x) )

# %%
"""
   Exportar los kilometros recorridos de acuerdo a cada id_ot del año 2023
"""

df_recorridos_2023 = df_recorridos[ df_recorridos.anio == '2023']

# %% [markdown]
# ##### Sample the Dataframe

# %%
df_recorridos_2023.sample(5)
# Out:
#         id_ot kmInicial  kmFinal                             fecha        dia  \
# 19158  120704    98,247   98,436  martes, 19 de diciembre del 2023     martes
# 15353  105955    56,630   56,664       lunes, 24 de abril del 2023      lunes
# 17706  113035   266,216  266,283  miércoles, 16 de agosto del 2023  miércoles
# 16987  108488         0        0       lunes, 05 de junio del 2023      lunes
# 17846  116671   327,928  327,954    jueves, 12 de octubre del 2023     jueves
#
#        anio  odo_inicial  odo_final  kmRecorridos
# 19158  2023        98247      98436           189
# 15353  2023        56630      56664            34
# 17706  2023       266216     266283            67
# 16987  2023            0          0             0
# 17846  2023       327928     327954            26

# %%
df_recorridos_2023.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4306 entries, 6627 to 19255
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id_ot         4306 non-null   object
#  1   kmInicial     4306 non-null   object
#  2   kmFinal       4306 non-null   object
#  3   fecha         4306 non-null   object
#  4   dia           4306 non-null   object
#  5   anio          4306 non-null   object
#  6   odo_inicial   4306 non-null   int64
#  7   odo_final     4306 non-null   int64
#  8   kmRecorridos  4306 non-null   int64
# dtypes: int64(3), object(6)
# memory usage: 336.4+ KB

# %%
df_recorridos_2023['kmRecorridos'].describe()
# Out:
# count      4306.000000
# mean        119.633767
# std        2156.053106
# min           0.000000
# 25%          24.250000
# 50%          73.000000
# 75%         109.000000
# max      100100.000000
# Name: kmRecorridos, dtype: float64

# %%
# Ajuste de valores erroneos
df_recorridos_2023.loc[15718,'kmRecorridos'] = 31

# %%
df_recorridos_2023
# Out:
#                              id_ot kmInicial  kmFinal  \
# 6627   sábado 10 de junio del 2023         ·        ·
# 14942                       110420   264,044  264,128
# 14943                       110454         0        0
# 14944                       110448   264,128  264,213
# 14945                       110508   264,213  264,301
# ...                            ...       ...      ...
# 19251                       121123    71,883   71,994
# 19252                       121196    71,994   72,019
# 19253                       120950         0        0
# 19254                       121339         0        0
# 19255                       121269    72,019   72,161
#
#                                      fecha        dia  anio  odo_inicial  \
# 6627          sábado, 10 de junio del 2023     sábado  2023            0
# 14942          lunes, 03 de julio del 2023      lunes  2023       264044
# 14943          lunes, 03 de julio del 2023      lunes  2023            0
# 14944         martes, 04 de julio del 2023     martes  2023       264128
# 14945      miércoles, 05 de julio del 2023  miércoles  2023       264213
# ...                                    ...        ...   ...          ...
# 19251  miércoles, 27 de diciembre del 2023  miércoles  2023        71883
# 19252     jueves, 28 de diciembre del 2023     jueves  2023        71994
# 19253      lunes, 25 de diciembre del 2023      lunes  2023            0
# 19254    viernes, 29 de diciembre del 2023    viernes  2023            0
# 19255    viernes, 29 de diciembre del 2023    viernes  2023        72019
#
#        odo_final  kmRecorridos
# 6627           0             0
# 14942     264128            84
# 14943          0             0
# 14944     264213            85
# 14945     264301            88
# ...          ...           ...
# 19251      71994           111
# 19252      72019            25
# 19253          0             0
# 19254          0             0
# 19255      72161           142
#
# [4306 rows x 9 columns]

# %%
# Exportar a Excel.

df_recorridos_2023.to_excel('kilometrajes_DICIEMBRE_2023_for_R.xlsx')

# %% [markdown]
# #### Una vez se tiene las columnas de fechaInicio y fechaFin y tiempo

# %%
matriz_actividades.iloc[1095]
# Out:
# uuid                             256d06b7-cb82-40ed-9124-138a594af8d6
# item                                                               10
# confianza                                                         0.0
# cuenta                                                     511.04.002
# evento              Zamora barrio Tunantza en la est. No. 179928 s...
# redes                                                             ALI
# alimentador                                                 Zamora II
# tipo                                                       CORRECTIVO
# actividad                                                        PROG
# cuadrilla                            Zamora Z1 (Cuadrilla. AP Nro. 4)
# primario                                                        False
# fechaInicio                                       2023-12-04 14:43:00
# fechaFin                                          2023-10-04 15:02:00
# horasExtra                                                      False
# desconexion                                                     False
# responsable                               MORALES RIVERA LUIS ALBERTO
# colaboradores       ROBLES JAEN SERVIO VINICIO;YAURE DIAZ RAMIRO G...
# vehiculo                                                         2-91
# sitio                                              Zamora, Gualaquiza
# dia                                                             lunes
# fecha                                                      2023-12-04
# id_ot                                                         119,735
# archivo             Orden de trabajo Alumbrado Zamora 04-12-2023 (...
# fechaInicio_time                                  2023-12-04 14:43:00
# tiempo                                             -61 days +00:19:00
# Name: 1095, dtype: object

# %% [markdown]
# #### Opcional, cargar archivo Pickle desde memoria   🔙  DESDE AQUI

# %% [markdown]
# ## Exportar a Excel la Matriz de Actividades
#
# **FALTA**:
#
#  - ~~Calificar la actividad~~.
#  - ~~Normalizar~~ las fechas a un solo formato, preferible con - en lugar de /
#  - Falta corregir las fechas en las actividades con Moda.
#  - Arbol de decision para casos específicos. Cuentas especiales
#  - Calcular el tiempo en formato H:MM ⏯ se tiene tiempo en formato DateTimeObj

# %% [markdown]
# #### Calcular tiempo transcurrido en HH:MM

# %%
matriz_actividades['tiempo'] = (matriz_actividades['fechaFin'] -   matriz_actividades['fechaInicio']).astype({'date': 'datetime64[m]'})

# %%
matriz_actividades.iloc[1000]
# Out:
# uuid                             7dd21104-efcb-480d-8cfb-1fca6f22267c
# item                                                                9
# confianza                                                         0.0
# cuenta                                                              ·
# evento              SE LABORA: EP de 08:00 a 13:00 y de 14:00 a 18:21
# redes                                                               ·
# alimentador                                                         ·
# tipo                                                                ·
# actividad                                                      LABORA
# cuadrilla                                       Jefatura Zonal Zamora
# primario                                                        False
# fechaInicio                                       2023-12-12 00:00:01
# fechaFin                                          2023-12-12 00:00:02
# horasExtra                                                      False
# desconexion                                                     False
# responsable                          PALACIOS MERINO ERNESTO VLADIMIR
# colaboradores                                                       ·
# vehiculo                                                            ·
# sitio                                                          Zamora
# dia                                                            martes
# fecha                                                      2023-12-12
# id_ot                                                         121,226
# archivo             Orden de trabajo Jefe Zonal Zamora 12-12-2023 ...
# fechaInicio_time                                  2023-12-12 00:00:01
# tiempo                                                0 days 00:00:01
# Name: 1000, dtype: object

# %%
matriz_actividades.sample(3)
# Out:
#                                       uuid  item  confianza      cuenta  \
# 2491  676c8198-686c-4c1f-a807-b06ab49c25e6     3        0.0  511.04.001
# 11    4ec59a2a-595b-4988-a5d6-0d4f852ec949     3        0.0  511.05.002
# 1760  929c7ba7-9441-4513-a76b-2ae122e14c09     4        0.0  511.04.001
#
#                                                  evento redes alimentador  \
# 2491  En Shaime, Est 61990 se repone tirafusible de ...   ALI    Paquisha
# 11                   SE LABORA: RS, LS de 02:20 a 03:38     ·           ·
# 1760                           LUNCH en el mismo sector     ·           ·
#
#             tipo actividad                        cuadrilla  ...  \
# 2491  CORRECTIAS      PROG  Guayzimi Z1 (Cuadrilla. Nro. 7)  ...
# 11             ·    LABORA    Zamora Z1 (Cuadrilla. Nro. 6)  ...
# 1760  ALIMENTACI    ALIMEN  Yacuambi Z1 (Cuadrilla. Nro. 8)  ...
#
#                             responsable  \
# 2491  CACAY LUZURIAGA ASDRUBAL HUMBERTO
# 11          SILVA ARMIJOS ROMEL EDUARDO
# 1760      CABRERA GONZALEZ WILMER DAVID
#
#                                           colaboradores vehiculo  \
# 2491                        LARA JIMENEZ JAIME PATRICIO    R-126
# 11    LEON CUEVA LUIS ALBERTO;SONGOR CARRION LUIS AL...    2-110
# 1760                      ZHUNAULA GUAMAN VICTOR ANIBAL    R-142
#
#                          sitio      dia       fecha    id_ot  \
# 2491     Shaime, Nuevo paraíso  domingo  2023-12-24  120,946
# 11             Zamora, Timbara  viernes  2023-12-01  119,674
# 1760  Yacuambi, Nuevo Porvenir  viernes  2023-12-29  121,268
#
#                                             archivo    fechaInicio_time  \
# 2491  Orden de trabajo Guayzimi 24-12-2023 (AC).pdf 2023-12-24 10:15:00
# 11      Orden de trabajo Zamora 01-12-2023 (RS).pdf 2023-12-01 00:00:01
# 1760  Orden de trabajo Yacuambi 29-12-2023 (WC).pdf 2023-12-29 12:45:00
#
#               tiempo
# 2491 0 days 00:25:00
# 11   0 days 00:00:01
# 1760 0 days 00:45:00
#
# [3 rows x 25 columns]

# %%
excel_format = matriz_actividades[[
                    'cuenta',
                    'evento',
                    'alimentador',
                    'tipo',
                    'actividad',
                    'cuadrilla',
                    'primario',
                    'fechaInicio',
                    'fechaFin',
                    'tiempo',
                    'horasExtra',
                    'desconexion',
                    'id_ot',
                    'responsable',
                    'vehiculo',
                    'sitio',
                    'archivo'
                 ]]

# %%
excel_format.to_excel( guardar_Excel, index=False )

# %%
excel_format.sample(5)
# Out:
#           cuenta                                             evento  \
# 1679  511.05.002  Nos trasladamos a Chamico, Nambija Bajo, Zamor...
# 1147  511.05.001  En la agencia de la EERSSA Zamora se coordina ...
# 3044  511.05.001  Se labora LP - RCL de 08:00 a 13:00 y de 14:00...
# 2773  511.05.001  Agencia, recepción documentos, planificación a...
# 728   511.05.001  Traslado del sector de Shiram Entnza, San Manu...
#
#      alimentador        tipo actividad                          cuadrilla  \
# 1679           ·  TRANSPORTE    TRANSP    Yacuambi Z1 (Cuadrilla. Nro. 8)
# 1147           ·   RUTINARIA      PROG   Zamora Z1 (Cuadrilla. AP Nro. 4)
# 3044           ·           ·    LABORA                 Yantzaza (Agencia)
# 2773           ·   RUTINARIA      PROG               Gualaquiza (Agencia)
# 728            ·  TRANSPORTE    TRANSP  Gualaquiza Z1 (Cuadrilla. Nro. 3)
#
#       primario         fechaInicio            fechaFin          tiempo  \
# 1679     False 2023-12-20 18:18:00 2023-12-20 18:30:00 0 days 00:12:00
# 1147     False 2023-12-11 08:00:00 2023-12-11 09:15:00 0 days 01:15:00
# 3044     False 2023-12-22 00:00:01 2023-12-22 00:00:02 0 days 00:00:01
# 2773     False 2023-12-28 08:00:00 2023-12-28 08:30:00 0 days 00:30:00
# 728      False 2023-12-03 16:05:00 2023-12-03 17:12:00 0 days 01:07:00
#
#       horasExtra  desconexion    id_ot                    responsable  \
# 1679       False        False  120,784  CABRERA GONZALEZ WILMER DAVID
# 1147       False        False  120,147    MORALES RIVERA LUIS ALBERTO
# 3044       False        False  120,906       POMA GUAMAN LUIS ANTONIO
# 2773       False        False  121,187  BUELE UYAGUARI CESAR CRISTIAN
# 728        False        False  119,774     LITUMA CORDOVA CESAR RUBEN
#
#      vehiculo                                            sitio  \
# 1679    R-142  Zamora, San Francisco de Cumbaratza, Las Palmas
# 1147    R-151                                           Zamora
# 3044    4-100                   YANTZAZA - ZUMBI - LA FLORIDA.
# 2773     R-12                    Gualaquiza La Paz, Guabi Alto
# 728     R-166                                      Gualaquiza.
#
#                                                 archivo
# 1679      Orden de trabajo Yacuambi 20-12-2023 (WC).pdf
# 1147  Orden de trabajo Alumbrado Zamora 11-12-2023 (...
# 3044  Orden de trabajo Yantzaza 22-12-2023 (LP - Ele...
# 2773  Orden de trabajo Gualaquiza 28-12-2023 (CB - E...
# 728     Orden de trabajo Gualaquiza 03-12-2023 (CL).pdf
